# %%
from tkinter import*
t=Tk()
b=Entry(t,text="enter here",bg="black",fg="green")
b.grid(columnspan=3)
m=Label(t,text="calculator")

m.grid(row=1,columnspan=3)
def clk(n):
        x=b.get()
        b.delete(0,END)
        b.insert(0,x+str(n))
        
        return
def badd():
    global m
    global n
    n='+'
    a=b.get()
    m=int(a)
    b.delete(0,END)
    return
def su():
    a=b.get()
    global m
    m=int(a)
    global n
    n='-'
    b.delete(0,END)
    return 
def mu():
    a=b.get()
    global m
    m=int(a)
    global n
    n='*'
    b.delete(0,END)
    return 
def di():
    a=b.get()
    global m
    m=int(a)
    global n
    n='/'
    b.delete(0,END)
    return
 
def clr():
    b.delete(0,END)
    return
    
def eql():
    s=b.get()
    f=int(s)
    b.delete(0,END)
    if(n=='+'):
        b.insert(0,f+m)
    if(n=='-'):
        b.insert(0,m-f)
    if(n=='*'):
        b.insert(0,f*m)
    if(n=='/'):
        b.insert(0,m/f)
        
    return
#asd    
a1=Button(t,text='1',padx=10,pady=10,command=lambda:clk(1))
a2=Button(t,text='2',padx=10,pady=10,command=lambda:clk(2))
a3=Button(t,text='3',padx=10,pady=10,command=lambda:clk(3))
a4=Button(t,text='4',padx=10,pady=10,command=lambda:clk(4))
a5=Button(t,text='5',padx=10,pady=10,command=lambda:clk(5))
a6=Button(t,text='6',padx=10,pady=10,command=lambda:clk(6))
a7=Button(t,text='7',padx=10,pady=10,command=lambda:clk(7))
a8=Button(t,text='8',padx=10,pady=10,command=lambda:clk(8))
a9=Button(t,text='9',padx=10,pady=10,command=lambda:clk(9))
a0=Button(t,text='0',padx=10,pady=10,command=lambda:(clk(0)))
plus=Button(t,text='+',padx=50,pady=10,command=lambda:badd())
sub=Button(t,text='-',padx=50,pady=10,command=lambda:su())
div=Button(t,text='/',padx=50,pady=10,command=lambda:di())
mul=Button(t,text='*',padx=50,pady=10,command=lambda:mu())
cl=Button(t,text="clear",padx=50,pady=10,command=lambda:clr())
eq=Button(t,text="equal",padx=50,pady=10,command=lambda:eql())


#view
a1.grid(row=2,column=0)
a2.grid(row=2,column=1)
a3.grid(row=2,column=2)
a4.grid(row=3,column=0)
a5.grid(row=3,column=1) 
a6.grid(row=3,column=2)
a7.grid(row=4,column=0)
a8.grid(row=4,column=1)
a0.grid(row=4,column=2)
cl.grid(row=5,column=0,columnspan=3)
eq.grid(row=6,column=0,columnspan=3)
plus.grid(row=7,column=0,columnspan=3)
sub.grid(row=8,column=0,columnspan=3)
mul.grid(row=9,column=0,columnspan=3)
div.grid(row=10,column=0,columnspan=3)
t.mainloop()
